# %%
from IPython.display import Image
from src.agent_graph import build_analysis_graph

# %%
graph = build_analysis_graph()

Image(graph.get_graph().draw_mermaid_png())

# %%
from src.tools.analyst_rating import check_analyst_ratings
check_analyst_ratings("TCS.NS")
# Out:
# INFO:src.tools.analyst_rating:Fetching analyst ratings for TCS.NS...
# INFO:src.tools.analyst_rating:Analyst ratings fetch completed for TCS.NS
# {'ticker': 'TCS.NS',
#  'target_price': 3469.6445,
#  'target_price_high': 4810.0,
#  'target_price_low': 1950.0,
#  'number_of_analysts': 45,
#  'recommendation_key': 'buy',
#  'recommendation': 'Buy'}

# %%
from src.tools.fundamental_analysis import perform_fundamental_analysis
perform_fundamental_analysis("TCS.NS")
# Out:
# INFO:src.tools.fundamental_analysis:Fetching fundamental data for TCS.NS...
# INFO:src.tools.fundamental_analysis:Fundamental analysis completed for TCS.NS
# {'ticker': 'TCS.NS',
#  'company_name': 'Tata Consultancy Services Limited',
#  'sector': 'Technology',
#  'industry': 'Information Technology Services',
#  'market_cap': 11716090920960,
#  'pe_ratio': 23.697037,
#  'forward_pe': 20.934834,
#  'ps_ratio': 4.546619,
#  'pb_ratio': 11.0098295,
#  'eps': 136.65,
#  'earnings_growth': 0.014,
#  'revenue': 2576879976448,
#  'revenue_per_share': 712.222,
#  'gross_profit': 1006889992192,
#  'operating_margin': 0.25183,
#  'profit_margin': 0.19186,
#  'debt_to_equity': 10.173,
#  'current_ratio': 2.433,
#  'roe': 0.47355998,
#  'roa': 0.23542,
#  'dividend_yield': 1.91,
#  'payout_ratio': 0.4465,
#  'book_value': 294.119,
#  '52_week_high': 4494.9,
#  '52_week_low': 2866.6,
#  'current_price': 3238.2}

# %%
from src.tools.risk_analysis import calculate_risk_metrics
calculate_risk_metrics("TCS.NS")
# Out:
# INFO:src.tools.risk_analysis:Calculating risk metrics for TCS.NS...
# INFO:src.tools.risk_analysis:Risk metrics calculation completed for TCS.NS
# {'ticker': 'TCS.NS',
#  'volatility_annual': np.float64(0.2003),
#  'beta': np.float64(0.9),
#  'sharpe_ratio': np.float64(-1.31),
#  'var_95': np.float64(-0.0197),
#  'max_drawdown': np.float64(-0.3628),
#  'volatility_assessment': 'Moderate Volatility'}

# %%
from src.tools.news_analysis import fetch_realtime_news
fetch_realtime_news("HDFC.NS")
# Out:
# INFO:src.tools.news_analysis:Fetching news for HDFC.NS...
# '(ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)), '(Request ID: 9c7ab463-8bb3-46a8-8aeb-2fdb0a7bac8d)')' thrown while requesting HEAD https://huggingface.co/mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis/resolve/main/config.json
# WARNING:huggingface_hub.utils._http:'(ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)), '(Request ID: 9c7ab463-8bb3-46a8-8aeb-2fdb0a7bac8d)')' thrown while requesting HEAD https://huggingface.co/mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis/resolve/main/config.json
# Retrying in 1s [Retry 1/5].
# WARNING:huggingface_hub.utils._http:Retrying in 1s [Retry 1/5].
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# Device set to use cpu
# INFO:src.tools.news_analysis:✓ News fetch completed for HDFC.NS (10 articles)
# {'ticker': 'HDFC.NS',
#  'total_articles_found': 2466,
#  'articles_fetched': 10,
#  'articles': [{'title': 'WASKO S.A.: Informacja o wyborze oferty',
#    'source': 'Bankier.pl',
#    'published_at': '2025-12-05T15:12:00Z',
#    'url': 'https://www.bankier.pl/wiadomosc/WASKO-S-A-Informacja-o-wyborze-oferty-9051348.html',
#    'description': 'Spis treści:1. RAPORT BIEŻĄCY2. MESSAGE (ENGLISH VERSION)3. INFORMACJE O PODMIOCIE4. PODPISY OSÓB REPREZENTUJĄCYCH SPÓŁKĘ td.td-text, th.td-text { word-break: keep-all; overflow-wrap: break-word; box-sizing: border-box;...',
#    'sentiment_score': 0.0},
#   {'title': 'Trends in Liquid Packaging Board Market 2025-2035',
#    'source': 'GlobeNewswire',
#    'published_at': '2025-12-05T15:10:00Z',
#    'url': 'https://www.globenewswire.com/news-release/2025/12/05/3200818/0/en/Trends-in-Liquid-Packaging-Board-Market-2025-2035.html',
#    'description': 'Liquid packaging board market is projected to expand from USD 44.71 billion in 2026 to USD 86.07 billion by 2034, recording a CAGR of 7.55%....',
#    'sentiment_score': 1.0},
#   {'title': 'Studio Ghibli adds new Kiki’s Delivery Service music box to its anime merchandise shop in Japan',
#    'source': 'SoraNews24',
#    'published_at': '2025-12-05T15:00:36Z',
#    'url': 'https://soranews24.com/2025/12/06/studio-ghibli-adds-new-kikis-delivery-service-music-box-to-its-anime-merchandise-shop-in-japan/',
#    'description': 'Heartfelt melody and sweet design features capture the magic of Jiji’s shop. At the centre of Studio Ghibli’s 1989 film Kiki’s Delivery Service is a young witch called Kiki, but in the years since the movie made its debut, her feline friend Jiji has been stea…',
#    'sentiment_score': 0.0},
#   {'title': 'Trisha Khalid Fulfils Promise, Attends TikToker’s Graduation After Family Fails to Attend',
#    'source': 'Breaking NEWS in KENYA for Today Right Now & Kenyan News | TUKO',
#    'published_at': '2025-12-05T14:57:43Z',
#    'url': 'https://www.tuko.co.ke/entertainment/celebrities/611785-trisha-khalid-fulfills-promise-attends-tiktokers-graduation-family-fails-attend/',
#    'description': 'Kenyan actress and content creator Trisha Khalid attended the graduation of a Kenyan TikToker whose family failed to attend. They shared videos online.',
#    'sentiment_score': -0.86},
#   {'title': 'CAPITAL: Opinia Rady Nadzorczej dotycząca projektów uchwał wniesionych do porządku obrad Nadzwyczajnego Walnego Zgromadzenia zwołanego dna dzień 31 grudnia 2025 roku',
#    'source': 'Bankier.pl',
#    'published_at': '2025-12-05T14:22:00Z',
#    'url': 'https://www.bankier.pl/wiadomosc/CAPITAL-Opinia-Rady-Nadzorczej-dotyczaca-projektow-uchwal-wniesionych-do-porzadku-obrad-Nadzwyczajnego-Walnego-Zgromadzenia-zwolanego-dna-dzien-31-grudnia-2025-roku-9051306.html',
#    'description': 'Spis treści:1. RAPORT BIEŻĄCY2. MESSAGE (ENGLISH VERSION)3. INFORMACJE O PODMIOCIE4. PODPISY OSÓB REPREZENTUJĄCYCH SPÓŁKĘ td.td-text, th.td-text { word-break: keep-all; overflow-wrap: break-word; box-sizing: border-box;...',
#    'sentiment_score': 0.0},
#   {'title': 'Trends in Amber Glass Packaging Market 2025-2035',
#    'source': 'GlobeNewswire',
#    'published_at': '2025-12-05T14:00:00Z',
#    'url': 'https://www.globenewswire.com/news-release/2025/12/05/3200732/0/en/Trends-in-Amber-Glass-Packaging-Market-2025-2035.html',
#    'description': 'According to Towards Packaging consultants, the global amber glass packaging market is projected to reach approximately USD 13.15 billion by 2034....',
#    'sentiment_score': 0.0},
#   {'title': 'Systematic computational assessment of atrial function impairment due to fibrotic remodeling in electromechanical properties',
#    'source': 'Plos.org',
#    'published_at': '2025-12-05T14:00:00Z',
#    'url': 'https://journals.plos.org/ploscompbiol/article?id=10.1371/journal.pcbi.1013265',
#    'description': 'Author summary Cardiac fibrosis is a process where healthy heart muscle is replaced with non-conductive, non-contractile tissue. This change disrupts how the heart beats and contracts. In the left atrium, fibrosis is linked to atrial fibrillation and a higher…',
#    'sentiment_score': 0.0},
#   {'title': 'A dendritic guidance receptor functions in both ligand dependent and independent modes',
#    'source': 'Plos.org',
#    'published_at': '2025-12-05T14:00:00Z',
#    'url': 'https://journals.plos.org/plosgenetics/article?id=10.1371/journal.pgen.1011942',
#    'description': 'Author summary Formation of a dendritic arbor requires the balancing between outgrowth and stabilization. Here, we aim to understand how this coordination is achieved at the molecular level. Stereotyped arborization of the C. elegans PVD neuron requires a tri…',
#    'sentiment_score': 0.0},
#   {'title': 'Impact of pregabalin reclassification as a controlled substance in Egypt on gabapentinoid and opioid utilization: A repeated cross-sectional study',
#    'source': 'Plos.org',
#    'published_at': '2025-12-05T14:00:00Z',
#    'url': 'https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0337833',
#    'description': 'Background Pregabalin is commonly used for treating pain but is also recognized for its misuse potential. In response to rising abuse, Egyptian health authorities reclassified pregabalin as a controlled substance in August 2019, aiming to curb misuse and regu…',
#    'sentiment_score': 0.0},
#   {'title': 'Correction: Catecholamines reduce choice history biases in perceptual decision making',
#    'source': 'Plos.org',
#    'published_at': '2025-12-05T14:00:00Z',
#    'url': 'https://journals.plos.org/plosbiology/article?id=10.1371/journal.pbio.3003548',
#    'description': None,
#    'sentiment_score': 0.0}],
#  'overall_sentiment_score': 0.014,
#  'sentiment_label': 'Neutral'}

# %%
from src.tools.technical_analysis import get_technical_indicators
get_technical_indicators("TCS.NS")
# Out:
# INFO:src.tools.technical_analysis:Calculating technical indicators for TCS.NS...
# INFO:src.tools.technical_analysis:Technical analysis completed for TCS.NS
# {'ticker': 'TCS.NS',
#  'analysis_period_days': 200,
#  'current_price': 3238.199951171875,
#  'price_change': -634.349365234375,
#  'price_change_pct': -16.380665897446985,
#  'sma_50': 3047.5485107421873,
#  'sma_200': 3253.0451318359374,
#  'golden_cross_status': 'Death Cross (Bearish)',
#  'rsi': 73.0,
#  'rsi_signal': 'Overbought - Potential Sell Signal',
#  'avg_volume': np.float64(2809596.0),
#  'current_volume': np.int64(5244013),
#  'volume_trend': 'High',
#  'high_52w': np.float64(3885.4910153447763),
#  'low_52w': np.float64(2855.9483563860495)}
